# %% [markdown]
# # Python Novice Final Exercice

# %% [markdown]
# ## First step : Configure repositoryand Download data
#
# 1. Create a git repository
# 1. Create a folder ```data```
# 1. Go to https://doi.org/10.25678/000172
# 1. Download **[score_amphetamine_wastewater_loads_2011_2017.csv](https://opendata.eawag.ch/dataset/8a5dd9ed-b9f8-4dea-a4fa-6e8d80c12bc6/resource/939eb064-7070-422f-9f72-61344a4bc28f/download/score_amphetamine_wastewater_loads_2011_2017.csv)** and **[score_benzoylecgonine_wastewater_loads_2011_2017.csv](https://opendata.eawag.ch/dataset/8a5dd9ed-b9f8-4dea-a4fa-6e8d80c12bc6/resource/6a0598d1-b764-4b6c-9846-9cd0ea9225f2/download/score_benzoylecgonine_wastewater_loads_2011_2017.csv)**
# 1. Move the ```.csv```files into ```data```

# %% [markdown]
# ## Load data and first contact

# %% [markdown]
# 1. Load the csv files into two separates variables (hint : use *pandas*)
# 1. Make sure all the coluns are detected correctly
# 1. Use the first colunms as index
# 1. Have a look of the columns and try to understand them, if you need help there is a *README.txt* with the data website

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
amphetamine_ori=pd.read_csv('./data/score_amphetamine_wastewater_loads_2011_2017.csv',delimiter=";",index_col=0)
benzoylec_orgi=pd.read_csv('./data/score_benzoylecgonine_wastewater_loads_2011_2017.csv',delimiter=";",index_col=0)

# %%
amphetamine_ori.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 132 entries, Innsbruck to Seattle
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          132 non-null    object
#  1   2011 population  18 non-null     float64
#  2   2012 population  27 non-null     float64
#  3   2013 population  45 non-null     float64
#  4   2014 population  61 non-null     float64
#  5   2015 population  69 non-null     float64
#  6   2016 population  70 non-null     float64
#  7   2017 population  78 non-null     float64
#  8   2011 mean        16 non-null     float64
#  9   2012 mean        27 non-null     float64
#  10  2013 mean        43 non-null     float64
#  11  2014 mean        58 non-null     float64
#  12  2015 mean        68 non-null     float64
#  13  2016 mean        70 non-null     float64
#  14  2017 mean        78 non-null     float64
#  15  2011 min         14 non-null     float64
#  16  2012 min         17 non-null     float64
#  17  2013 min         35 non-null     float64
#  18  2014 min         47 non-null     float64
#  19  2015 min         55 non-null     float64
#  20  2016 min         59 non-null     float64
#  21  2017 min         62 non-null     float64
#  22  2011 max         14 non-null     float64
#  23  2012 max         17 non-null     float64
#  24  2013 max         35 non-null     float64
#  25  2014 max         47 non-null     float64
#  26  2015 max         55 non-null     float64
#  27  2016 max         59 non-null     float64
#  28  2017 max         62 non-null     float64
#  29  2011 sd          14 non-null     float64
#  30  2012 sd          17 non-null     float64
#  31  2013 sd          35 non-null     float64
#  32  2014 sd          47 non-null     float64
#  33  2015 sd          55 non-null     float64
#  34  2016 sd          59 non-null     float64
#  35  2017 sd          62 non-null     float64
# dtypes: float64(35), object(1)
# memory usage: 38.2+ KB

# %%
amphetamine_ori
# Out:
#                country  2011 population  2012 population  2013 population  \
# Innsbruck           AT              NaN              NaN              NaN
# Klosterneuburg      AT              NaN              NaN              NaN
# Adelaide (4)        AU              NaN              NaN              NaN
# Canberra            AU              NaN              NaN              NaN
# Toowoomba           AU              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# Ljubljana           SI              NaN              NaN              NaN
# Bratislava (2)      SK              NaN              NaN         440000.0
# Piestany            SK              NaN              NaN          30000.0
# Uzhhorod            UA              NaN              NaN              NaN
# Seattle             US              NaN              NaN              NaN
#
#                 2014 population  2015 population  2016 population  \
# Innsbruck                   NaN              NaN         262780.0
# Klosterneuburg              NaN          30000.0              NaN
# Adelaide (4)                NaN              NaN              NaN
# Canberra               338888.0         338888.0              NaN
# Toowoomba              125000.0         125000.0              NaN
# ...                         ...              ...              ...
# Ljubljana                   NaN              NaN              NaN
# Bratislava (2)              NaN         470000.0         470000.0
# Piestany                    NaN          30000.0          30000.0
# Uzhhorod                    NaN              NaN         116200.0
# Seattle                     NaN         893000.0         893000.0
#
#                 2017 population  2011 mean  2012 mean  ...   2015 max  \
# Innsbruck              261503.0        NaN        NaN  ...        NaN
# Klosterneuburg              NaN        NaN        NaN  ...        NaN
# Adelaide (4)          1133475.0        NaN        NaN  ...        NaN
# Canberra               390706.0        NaN        NaN  ...  30.084499
# Toowoomba              125000.0        NaN        NaN  ...  26.538035
# ...                         ...        ...        ...  ...        ...
# Ljubljana              266131.0        NaN        NaN  ...        NaN
# Bratislava (2)         600000.0        NaN        NaN  ...  30.881468
# Piestany                30000.0        NaN        NaN  ...  33.642000
# Uzhhorod                    NaN        NaN        NaN  ...        NaN
# Seattle                893000.0        NaN        NaN  ...  87.236660
#
#                   2016 max    2017 max  2011 sd  2012 sd   2013 sd   2014 sd  \
# Innsbruck        21.468909   22.607580      NaN      NaN       NaN       NaN
# Klosterneuburg         NaN         NaN      NaN      NaN       NaN       NaN
# Adelaide (4)           NaN   37.892498      NaN      NaN       NaN       NaN
# Canberra               NaN   26.505736      NaN      NaN       NaN  2.464238
# Toowoomba              NaN   68.705684      NaN      NaN       NaN  1.798143
# ...                    ...         ...      ...      ...       ...       ...
# Ljubljana              NaN   41.013343      NaN      NaN       NaN       NaN
# Bratislava (2)   90.125011   15.184903      NaN      NaN  2.389922       NaN
# Piestany         44.748800    5.026933      NaN      NaN  2.369657       NaN
# Uzhhorod         11.978055         NaN      NaN      NaN       NaN       NaN
# Seattle         114.126558  180.950398      NaN      NaN       NaN       NaN
#
#                  2015 sd    2016 sd    2017 sd
# Innsbruck            NaN   4.815182   4.726365
# Klosterneuburg       NaN        NaN        NaN
# Adelaide (4)         NaN        NaN   2.425303
# Canberra        3.004366        NaN   2.583573
# Toowoomba       2.881866        NaN   6.634324
# ...                  ...        ...        ...
# Ljubljana            NaN        NaN   3.893277
# Bratislava (2)  3.843428  14.053016   3.534692
# Piestany        8.513295   8.329841   1.816877
# Uzhhorod             NaN   1.759686        NaN
# Seattle         8.467401  22.750185  27.564828
#
# [132 rows x 36 columns]

# %% [markdown]
# ## Create a subset of the data
# * Create two dataframe that only containts data from switzerland for both molecule

# %%
amphetamine_swiss=amphetamine_ori[amphetamine_ori['country']=="CH"]

# %%
benzoylec_swiss=benzoylec_orgi[benzoylec_orgi['country']=="CH"]

# %%
amphetamine_swiss
# Out:
#               country  2011 population  2012 population  2013 population  \
# Basel              CH              NaN         260000.0         260000.0
# Berne              CH              NaN         206655.0         206655.0
# Biel               CH              NaN              NaN              NaN
# Chur               CH              NaN              NaN              NaN
# Geneva             CH              NaN         410486.0         410486.0
# Lausanne           CH              NaN              NaN              NaN
# Lugano             CH              NaN              NaN              NaN
# Luzern             CH              NaN              NaN              NaN
# Neuchatel          CH              NaN              NaN              NaN
# Sion               CH              NaN              NaN              NaN
# St.Gallen (2)      CH              NaN          89000.0          89000.0
# St.Gallen A        CH              NaN          37000.0          37000.0
# St.Gallen H        CH              NaN          52000.0          52000.0
# Winterthur         CH              NaN              NaN              NaN
# Zurich             CH              NaN         410000.0         410000.0
#
#                2014 population  2015 population  2016 population  \
# Basel                 260000.0         260000.0         260000.0
# Berne                 206655.0         206655.0         206655.0
# Biel                   82285.0              NaN              NaN
# Chur                   52800.0          52800.0              NaN
# Geneva                417200.0         417200.0         417200.0
# Lausanne              220000.0         220000.0              NaN
# Lugano                103561.0         103561.0         103561.0
# Luzern                174800.0         174800.0              NaN
# Neuchatel              50000.0          50000.0              NaN
# Sion                   45000.0          45000.0              NaN
# St.Gallen (2)              NaN              NaN              NaN
# St.Gallen A                NaN              NaN              NaN
# St.Gallen H            52000.0          52000.0          52000.0
# Winterthur            125000.0         125000.0              NaN
# Zurich                410000.0         410000.0         410000.0
#
#                2017 population  2011 mean  2012 mean  ...   2015 max  \
# Basel                 260000.0        NaN    0.00000  ...  49.775769
# Berne                 206655.0        NaN   33.04802  ...  39.028526
# Biel                       NaN        NaN        NaN  ...        NaN
# Chur                       NaN        NaN        NaN  ...  24.956067
# Geneva                417200.0        NaN   38.95967  ...   7.423586
# Lausanne                   NaN        NaN        NaN  ...  13.303921
# Lugano                     NaN        NaN        NaN  ...        NaN
# Luzern                     NaN        NaN        NaN  ...  63.610854
# Neuchatel                  NaN        NaN        NaN  ...  34.329101
# Sion                       NaN        NaN        NaN  ...  17.027930
# St.Gallen (2)              NaN        NaN    0.00000  ...        NaN
# St.Gallen A                NaN        NaN    0.00000  ...        NaN
# St.Gallen H            52000.0        NaN    0.00000  ...  42.069808
# Winterthur                 NaN        NaN        NaN  ...  40.608000
# Zurich                410000.0        NaN    0.00000  ...  37.334634
#
#                 2016 max   2017 max  2011 sd    2012 sd    2013 sd    2014 sd  \
# Basel          31.319610  40.585385      NaN        NaN  15.368784   7.278478
# Berne          27.544982  66.847293      NaN   6.096153   4.925079   1.901207
# Biel                 NaN        NaN      NaN        NaN        NaN   5.626369
# Chur                 NaN        NaN      NaN        NaN        NaN   5.056373
# Geneva         15.704749  20.892700      NaN  27.740699        NaN        NaN
# Lausanne             NaN        NaN      NaN        NaN        NaN   2.978760
# Lugano               NaN        NaN      NaN        NaN        NaN        NaN
# Luzern               NaN        NaN      NaN        NaN        NaN   9.094934
# Neuchatel            NaN        NaN      NaN        NaN        NaN   3.244834
# Sion                 NaN        NaN      NaN        NaN        NaN        NaN
# St.Gallen (2)        NaN        NaN      NaN        NaN        NaN        NaN
# St.Gallen A          NaN        NaN      NaN        NaN  70.118665        NaN
# St.Gallen H    46.926417  49.491346      NaN        NaN        NaN  64.267683
# Winterthur           NaN        NaN      NaN        NaN        NaN   4.940825
# Zurich         47.570476  54.889560      NaN        NaN  19.142151  14.237926
#
#                  2015 sd   2016 sd   2017 sd
# Basel          16.841213  2.938167  5.220504
# Berne           7.208052  2.816455  9.070552
# Biel                 NaN       NaN       NaN
# Chur            4.621620       NaN       NaN
# Geneva          1.010187  4.628308  3.150347
# Lausanne        1.999570       NaN       NaN
# Lugano               NaN       NaN       NaN
# Luzern         14.330599       NaN       NaN
# Neuchatel       7.475753       NaN       NaN
# Sion            3.836393       NaN       NaN
# St.Gallen (2)        NaN       NaN       NaN
# St.Gallen A          NaN       NaN       NaN
# St.Gallen H     6.565480  8.111481  4.312347
# Winterthur      7.100932       NaN       NaN
# Zurich          6.260402  8.660888  4.310203
#
# [15 rows x 36 columns]

# %% [markdown]
# ## Plotting
# *Use only the ampehtamine array*
# 1. Plot the average for the 8th first location from 2011 to 2017 with a [bar graph](https://pandas.pydata.org/docs/user_guide/visualization.html#other-plots)
#
# Extra : Plot the error bar (standard deviation) using ```yerr``` [See doc](https://pandas.pydata.org/docs/user_guide/visualization.html#plotting-with-error-bars)
#
# *Hint for extra* : the columns name of the yerr dataframe columns should have the same name that the dataframe plotted

# %%
amphetamine_swiss.iloc[:8].loc[:, "2011 mean":"2017 mean"].plot(kind='bar',figsize=(12, 12))

# %% [markdown]
# ### With error bar

# %%
error=amphetamine_swiss.iloc[:8].loc[:, "2011 sd":"2017 sd"]
error.columns=amphetamine_swiss.iloc[:8].loc[:, "2011 mean":"2017 mean"].columns
amphetamine_swiss.iloc[:8].loc[:, "2011 mean":"2017 mean"].plot(kind='bar',figsize=(12, 12),yerr=error,capsize=4)

# %% [markdown]
# ## Average per country
# Calculate the average for each country, put it into a function that take a dataframe as input and print the results
#
# *hint*:
# 1. Create a list that will have the country name (*hint* you can use the ```unique()``` method)
# 1. Use a for loop over all the element of this list
# 1. Inside the loop create a subset dataframe for this give country
# 1. Calculate the average (using ```mean()``` method) of this subset for the correct columns (you might have to do ```mean()``` two times)
# 1. Print the average with the country name

# %%
def average_percountry(dataframe):
    list_country=dataframe["country"].unique()
    for country in list_country:
        subset=dataframe[dataframe['country']==country]
        mean=subset.loc[:, "2011 mean":"2017 mean"].mean()
        mean=mean.mean()
        print(country, ':',mean)
average_percountry(amphetamine_ori)
# Out:
# AT : 9.088747546666667
# AU : 27.753837904444442
# BA : 89.79779121
# BE : 127.11006768025
# BG : 29.11224583
# CA : 29.80822470475
# CH : 23.15548062682036
# CO : 0.0
# CY : 5.1813180605
# CZ : 21.987912178583333
# DE : 71.37625137846666
# DK : 22.660749395
# ES : 11.205586303714284
# FI : 61.13332020678572
# FR : 0.0
# GB : 37.828403263333335
# GR : 7.308594179799999
# HR : 36.80755174071429
# IL : 2.805224506
# IS : 131.93413425
# IT : 2.295806886333333
# KR : 1.316588434
# LI : 38.11564942
# LT : 13.07611974
# MT : 3.717411416
# NL : 977.5498959473811
# NO : 77.76343524666667
# NZ : 11.02879216
# PL : 31.667101465000002
# PT : 1.0660118543333332
# RO : 0.609593254
# RS : 19.194026085
# SE : 99.39388025708334
# SI : 35.23761928
# SK : 23.548835869999998
# UA : 10.5248494
# US : 93.58139508

# %% [markdown]
# ### Average per country output
#
# Take the previous function
#
# Now we would like to return a dataframe with the average values per country and the country name as index
#
# To create a dataframe you can use : ```pd.DataFrame(_List_, index=_List_,columns=_List_)```
#
# *hint* : Put the result of each country on a list then create the dataframe after the loop.
#
# **Extra 1**: Remove country that have an average lower than zero.
#
# **Extra 2**: add the averaged standard deviation to the dataframe
#
# * You then can plot the result in a bar graph
# * You can also save this dataframe using ```to_csv()``` method [See Doc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html?highlight=to_csv#pandas.DataFrame.to_csv)
# * Try using the second molecule

# %%
def average_percountry(dataframe):
    list_country=dataframe["country"].unique()
    outlist=[]
    for country in list_country:
        subset=dataframe[dataframe['country']==country]
        mean=subset.loc[:, "2011 mean":"2017 mean"].mean().mean()

        outlist.append(mean)
    df=pd.DataFrame(outlist, index=list_country,columns=["average",])
    return df
average_percountry(amphetamine_ori).plot(kind='bar',figsize=(12, 12))

# %% [markdown]
# ### With error bar and removed null average

# %%
def average_percountry(dataframe):
    list_country=dataframe["country"].unique()
    outlist=[]
    for country in list_country:
        subset=dataframe[dataframe['country']==country]
        mean=subset.loc[:, "2011 mean":"2017 mean"].mean().mean()
        std=subset.loc[:, "2011 sd":"2017 sd"].mean().mean()

        outlist.append([mean,std])
    df=pd.DataFrame(outlist, index=list_country,columns=["average","std"])
    return df[df["average"]>0]
var=average_percountry(amphetamine_ori)
var['average'].plot(kind='bar',figsize=(12, 12),yerr=var['std'],capsize=4)

# %% [markdown]
# ### Make a csv file

# %%
var.to_csv('amphetamine_mean_percountry.csv')

# %% [markdown]
# ## Try with benzoylecgonine

# %%
average_percountry(benzoylec_orgi)
# Out:
#        average         std
# AT  156.040772   37.308372
# AU   43.802064   19.077737
# BA   45.035399   13.127892
# BE  369.260773   66.588585
# BG   34.135643    7.883142
# CA  221.618617   49.452310
# CH  412.753338  100.183573
# CO  524.227349   46.683296
# CY   77.931767   15.323462
# CZ   15.211078    5.940793
# DE  133.131741   32.052658
# DK  299.168556   98.579872
# ES  344.796373   95.303120
# FI    6.860706    3.777832
# FR  299.916667  104.567523
# GB  600.237798  165.030068
# GR   46.610037   10.187207
# HR  108.034998   28.287271
# IL   24.433664    6.793378
# IS  213.115400   50.205223
# IT  232.693490   37.301724
# LI  159.001319   53.484378
# LT   34.700791   19.163641
# MT   68.445169   21.468825
# NL  412.201804  106.820104
# NO  124.602647   39.662605
# NZ    4.919602    1.997144
# PL    8.005079    6.403061
# PT  122.353180   20.451775
# RO    0.553125    0.917069
# RS   21.852028    7.959106
# SE   51.593127   20.347207
# SI  449.755238   78.492135
# SK   36.894298    9.997811
# UA    1.016244    0.100870
# US  392.701593   88.955865

# %% [markdown]
# ## Make a script
# Make a script that:
# 1. open a csv file
# 1. Calculate the average of each country (function developped before)
# 1. save this average into another csv file with the pattern nameoffile_meanpercountry.csv

# %%
import pandas as pd

def average_percountry(dataframe):
    list_country=dataframe["country"].unique()
    outlist=[]
    for country in list_country:
        subset=dataframe[dataframe['country']==country]
        mean=subset.loc[:, "2011 mean":"2017 mean"].mean().mean()
        std=subset.loc[:, "2011 sd":"2017 sd"].mean().mean()

        outlist.append([mean,std])
    df=pd.DataFrame(outlist, index=list_country,columns=["average","std"])
    return df[df["average"]>0]
file="./data/score_benzoylecgonine_wastewater_loads_2011_2017"
data=pd.read_csv(file+".csv",delimiter=";",index_col=0)
avg_df=average_percountry(data)
avg_df.to_csv(file+"_meanpercountry.csv")

# %% [markdown]
# ## Publish the study
# * add a ```README.md``` that describe the project you can use markdown
# * Publish the entiere project (data,script and notebook) into a GitHub repository
